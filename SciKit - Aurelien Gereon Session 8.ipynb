# %%
#PCA
import os
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_openml

def sort_by_target(mnist):
    reorder_train = np.array(sorted([(target, i) for i, target in enumerate(mnist.target[:60000])]))[:, 1]
    reorder_test = np.array(sorted([(target, i) for i, target in enumerate(mnist.target[60000:])]))[:, 1]
    mnist.data[:60000] = mnist.data[reorder_train]
    mnist.target[:60000] = mnist.target[reorder_train]
    mnist.data[60000:] = mnist.data[reorder_test + 60000]
    mnist.target[60000:] = mnist.target[reorder_test + 60000]

try:
    from sklearn.datasets import fetch_openml
    mnist = fetch_openml('mnist_784', version=1, cache=True)
    mnist.target = mnist.target.astype(np.int8) # fetch_openml() returns targets as strings
    sort_by_target(mnist) # fetch_openml() returns an unsorted dataset
except ImportError:
    from sklearn.datasets import fetch_mldata
    mnist = fetch_mldata('MNIST original')
    
mnist = fetch_openml('mnist_784', version=1, cache=True)

X, y = mnist["data"], mnist["target"]

X_centered = X - X.mean(axis=0)
U, s, V = np.linalg.svd(X_centered)
c1 = V.T[:, 0]
c2 = V.T[:, 1]

W2 = V.T[:, :2] #this is the projection part
X2D = X_centered.dot(W2)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-3e2a31ac6c3a> in <module>
#      27
#      28 X_centered = X - X.mean(axis=0) #no idea what data is being used...
# ---> 29 U, s, V = np.linalg.svd(X_centered)
#      30 c1 = V.T[:, 0]
#      31 c2 = V.T[:, 1]
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# c:\python37\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1659
#    1660         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1661         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1662         u = u.astype(result_t, copy=False)
#    1663         s = s.astype(_realType(result_t), copy=False)
#
# MemoryError: Unable to allocate 36.5 GiB for an array with shape (70000, 70000) and data type float64

# %%
#Or simply use the Scikit-Learn library
from sklearn.decomposition import PCA
from sklearn.datasets import fetch_openml

def sort_by_target(mnist):
    reorder_train = np.array(sorted([(target, i) for i, target in enumerate(mnist.target[:60000])]))[:, 1]
    reorder_test = np.array(sorted([(target, i) for i, target in enumerate(mnist.target[60000:])]))[:, 1]
    mnist.data[:60000] = mnist.data[reorder_train]
    mnist.target[:60000] = mnist.target[reorder_train]
    mnist.data[60000:] = mnist.data[reorder_test + 60000]
    mnist.target[60000:] = mnist.target[reorder_test + 60000]

try:
    from sklearn.datasets import fetch_openml
    mnist = fetch_openml('mnist_784', version=1, cache=True)
    mnist.target = mnist.target.astype(np.int8) # fetch_openml() returns targets as strings
    sort_by_target(mnist) # fetch_openml() returns an unsorted dataset
except ImportError:
    from sklearn.datasets import fetch_mldata
    mnist = fetch_mldata('MNIST original')
    
mnist = fetch_openml('mnist_784', version=1, cache=True)

X, y = mnist["data"], mnist["target"]

pca = PCA(n_components = 2) #reducing dimensionality to two
'''pca = PCA() for no dimensionality reduction'''
X2D = pca.fit_transform(X)

# the variance ratio is visible this way
print(pca.explained_variance_ratio_)

#You can use this way to reduce dimensionality and keep 95% variance
pca = PCA()
pca.fit(X)
cumsum = np.cumsum(pca.explained_variance_ratio_)
d = np.argmax(cumsum >= 0.95) + 1

pca = PCA(n_components=0.95)
X_reduced = pca.fit_transform(X)

# with n_components you can decide the number of dimension you want to keep
pca = PCA(n_components = 154)
X_mnist_reduced = pca.fit_transform(X)

# this reconstitutes the original data with losses
X_mnist_recovered = pca.inverse_transform(X_mnist_reduced)
# Out:
# [0.09746116 0.07155445]

# %%
X_reduced

# %%
#Not enough memory on my computer to run this code...cool...

from sklearn.decomposition import IncrementalPCA

n_batches = 100

inc_pca = IncrementalPCA(n_components=154)
for X_batch in np.array_split(X, n_batches):
    inc_pca.partial_fit(X_batch)

X_mnist_reduced = inc_pca.transform(X)

# %%
# this seems to be a faster PCA method as well
from sklearn.decomposition import PCA

rnd_pca = PCA(n_components=154, svd_solver="randomized")
X_reduced = rnd_pca.fit_transform(X)

# Kernel PCA...for when I can test it
from sklearn.decomposition import KernelPCA

rbf_pca = KernelPCA(n_components = 2, kernel="rbf", gamma=0.04)
X_reduced = rbf_pca.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-617b31e7ae3f> in <module>
#       9
#      10 rbf_pca = KernelPCA(n_components = 2, kernel="rbf", gamma=0.04)
# ---> 11 X_reduced = rbf_pca.fit_transform(X)
#
# c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py in fit_transform(self, X, y, **params)
#     303         X_new : array-like, shape (n_samples, n_components)
#     304         """
# --> 305         self.fit(X, **params)
#     306
#     307         # no need to use the kernel to transform X, use shortcut expression
#
# c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py in fit(self, X, y)
#     278         X = self._validate_data(X, accept_sparse='csr', copy=self.copy_X)
#     279         self._centerer = KernelCenterer()
# --> 280         K = self._get_kernel(X)
#     281         self._fit_transform(K)
#     282
#
# c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py in _get_kernel(self, X, Y)
#     178         return pairwise_kernels(X, Y, metric=self.kernel,
#     179                                 filter_params=True, n_jobs=self.n_jobs,
# --> 180                                 **params)
#     181
#     182     def _fit_transform(self, K):
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\python37\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_kernels(X, Y, metric, filter_params, n_jobs, **kwds)
#    1938         raise ValueError("Unknown kernel %r" % metric)
#    1939
# -> 1940     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# c:\python37\lib\site-packages\sklearn\metrics\pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1358
#    1359     if effective_n_jobs(n_jobs) == 1:
# -> 1360         return func(X, Y, **kwds)
#    1361
#    1362     # enforce a threading backend to prevent data communication overhead
#
# c:\python37\lib\site-packages\sklearn\metrics\pairwise.py in rbf_kernel(X, Y, gamma)
#    1102         gamma = 1.0 / X.shape[1]
#    1103
# -> 1104     K = euclidean_distances(X, Y, squared=True)
#    1105     K *= -gamma
#    1106     np.exp(K, K)  # exponentiate K in-place
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\python37\lib\site-packages\sklearn\metrics\pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     308     else:
#     309         # if dtype is already float64, no need to chunk and upcast
# --> 310         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     311         distances += XX
#     312         distances += YY
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\python37\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# MemoryError: Unable to allocate 36.5 GiB for an array with shape (70000, 70000) and data type float64

# %%
# unsupervised learning
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ("kpca", KernelPCA(n_components=2)),
    ("log_reg", LogisticRegression())
])

param_grid = [{
    "kpca__gamma": np.linspace(0.03, 0.05, 10),
    "kpca__kernel": ["rbf", "sigmoid"]
}]
grid_search = GridSearchCV(clf, param_grid, cv=3)
grid_search.fit(X, y)
# Out:
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46666, 46666) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46666, 46666) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46666, 46666) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46666, 46666) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46666, 46666) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46666, 46666) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46666, 46666) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
# ...
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46666, 46666) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1070, in sigmoid_kernel
#     K = safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46667, 46667) and data type float64
#
#   FitFailedWarning)
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\python37\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "c:\python37\lib\site-packages\joblib\memory.py", line 329, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\python37\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 305, in fit_transform
#     self.fit(X, **params)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 280, in fit
#     K = self._get_kernel(X)
#   File "c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py", line 180, in _get_kernel
#     **params)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1940, in pairwise_kernels
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1360, in _parallel_pairwise
#     return func(X, Y, **kwds)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 1104, in rbf_kernel
#     K = euclidean_distances(X, Y, squared=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\metrics\pairwise.py", line 310, in euclidean_distances
#     distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#   File "c:\python37\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "c:\python37\lib\site-packages\sklearn\utils\extmath.py", line 153, in safe_sparse_dot
#     ret = a @ b
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (46666, 46666) and data type float64
#
#   FitFailedWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-450fed727b87> in <module>
#      14 }]
#      15 grid_search = GridSearchCV(clf, param_grid, cv=3)
# ---> 16 grid_search.fit(X, y)
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\python37\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# c:\python37\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# c:\python37\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# c:\python37\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     984                 self._iterating = self._original_iterator is not None
#     985
# --> 986             while self.dispatch_one_batch(iterator):
#     987                 pass
#     988
#
# c:\python37\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# c:\python37\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# c:\python37\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# c:\python37\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# c:\python37\lib\site-packages\joblib\parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# c:\python37\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# c:\python37\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# c:\python37\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     328         """
#     329         fit_params_steps = self._check_fit_params(**fit_params)
# --> 330         Xt = self._fit(X, y, **fit_params_steps)
#     331         with _print_elapsed_time('Pipeline',
#     332                                  self._log_message(len(self.steps) - 1)):
#
# c:\python37\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     294                 message_clsname='Pipeline',
#     295                 message=self._log_message(step_idx),
# --> 296                 **fit_params_steps[name])
#     297             # Replace the transformer of the step with the fitted
#     298             # transformer. This is necessary when loading the transformer
#
# c:\python37\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     327
#     328     def __call__(self, *args, **kwargs):
# --> 329         return self.func(*args, **kwargs)
#     330
#     331     def call_and_shelve(self, *args, **kwargs):
#
# c:\python37\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738     with _print_elapsed_time(message_clsname, message):
#     739         if hasattr(transformer, 'fit_transform'):
# --> 740             res = transformer.fit_transform(X, y, **fit_params)
#     741         else:
#     742             res = transformer.fit(X, y, **fit_params).transform(X)
#
# c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py in fit_transform(self, X, y, **params)
#     303         X_new : array-like, shape (n_samples, n_components)
#     304         """
# --> 305         self.fit(X, **params)
#     306
#     307         # no need to use the kernel to transform X, use shortcut expression
#
# c:\python37\lib\site-packages\sklearn\decomposition\_kernel_pca.py in fit(self, X, y)
#     276             Returns the instance itself.
#     277         """
# --> 278         X = self._validate_data(X, accept_sparse='csr', copy=self.copy_X)
#     279         self._centerer = KernelCenterer()
#     280         K = self._get_kernel(X)
#
# c:\python37\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      87     # safely to reduce dtype induced overflows.
#      88     is_float = X.dtype.kind in 'fc'
# ---> 89     if is_float and (np.isfinite(_safe_accumulator_op(np.sum, X))):
#      90         pass
#      91     elif is_float:
#
# c:\python37\lib\site-packages\sklearn\utils\extmath.py in _safe_accumulator_op(op, x, *args, **kwargs)
#     709         result = op(x, *args, **kwargs, dtype=np.float64)
#     710     else:
# --> 711         result = op(x, *args, **kwargs)
#     712     return result
#     713
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# c:\python37\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2240
#    2241     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2242                           initial=initial, where=where)
#    2243
#    2244
#
# c:\python37\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:

# %%
from sklearn.manifold import LocallyLinearEmbedding

lle = LocallyLinearEmbedding(n_components=2, n_neighbors=10)
X_reduced = lle.fit_transform(X)
